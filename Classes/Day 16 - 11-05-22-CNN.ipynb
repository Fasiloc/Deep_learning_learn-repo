# %% [markdown]
# # Pima Indians Onset of Diabetes Dataset

# %%
from keras.models import Sequential
from keras.layers import Dense
import numpy
# fix random seed for reproducibility
seed = 7
numpy.random.seed(seed)

# %%
# load pima indians dataset
dataset = numpy.loadtxt("pima-indians-diabetes.csv", delimiter=",")
# split into input (X) and output (Y) variables
X = dataset[:,0:8]
Y = dataset[:,8]

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dense, Flatten

# create model
model = Sequential()
model.add(Flatten())
model.add(Dense(12, activation = 'relu'))
model.add(Dense(8, activation = 'relu'))
model.add(Dense(1, activation = 'sigmoid'))

# %%
# Compile model
model.compile(loss= 'binary_crossentropy' , optimizer= 'adam', metrics=[ 'accuracy'])

# %%
# Fit the model
model.fit(X, Y, epochs=150, batch_size=10)
# Out:
# Epoch 1/150
# 77/77 [==============================] - 1s 1ms/step - loss: 35.6970 - accuracy: 0.3490
# Epoch 2/150
# 77/77 [==============================] - 0s 1ms/step - loss: 7.2609 - accuracy: 0.4284
# Epoch 3/150
# 77/77 [==============================] - 0s 1ms/step - loss: 1.0017 - accuracy: 0.5924
# Epoch 4/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.8448 - accuracy: 0.6159
# Epoch 5/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.7954 - accuracy: 0.6107
# Epoch 6/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.7382 - accuracy: 0.6341
# Epoch 7/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.7404 - accuracy: 0.6198
# Epoch 8/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.7041 - accuracy: 0.6367
# Epoch 9/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.7004 - accuracy: 0.6471
# Epoch 10/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.6838 - accuracy: 0.6406
# Epoch 11/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.6860 - accuracy: 0.6523
# Epoch 12/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.6729 - accuracy: 0.6406
# Epoch 13/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.6540 - accuracy: 0.6602
# Epoch 14/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.6514 - accuracy: 0.6589
# Epoch 15/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.6404 - accuracy: 0.6654
# Epoch 16/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.6332 - accuracy: 0.6680
# Epoch 17/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.6220 - accuracy: 0.7031
# Epoch 18/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.5980 - accuracy: 0.6953
# Epoch 19/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.5899 - accuracy: 0.7122
# Epoch 20/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.5883 - accuracy: 0.6901
# Epoch 21/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.6052 - accuracy: 0.6888
# Epoch 22/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.5794 - accuracy: 0.6888
# Epoch 23/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.5648 - accuracy: 0.7174
# Epoch 24/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.5937 - accuracy: 0.7122
# Epoch 25/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.5664 - accuracy: 0.7044
# Epoch 26/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.5626 - accuracy: 0.7240
# Epoch 27/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.5870 - accuracy: 0.6966
# Epoch 28/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.5603 - accuracy: 0.7188
# Epoch 29/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.5562 - accuracy: 0.7096
# Epoch 30/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.5450 - accuracy: 0.7422
# Epoch 31/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.5884 - accuracy: 0.7188
# Epoch 32/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.5661 - accuracy: 0.7096
# Epoch 33/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.5597 - accuracy: 0.7240
# Epoch 34/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.5469 - accuracy: 0.7227
# Epoch 35/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.5395 - accuracy: 0.7461
# Epoch 36/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.5432 - accuracy: 0.7461
# Epoch 37/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.5539 - accuracy: 0.7292
# Epoch 38/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.5555 - accuracy: 0.7188
# Epoch 39/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.5541 - accuracy: 0.7057
# Epoch 40/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.5418 - accuracy: 0.7357
# Epoch 41/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.5683 - accuracy: 0.7018
# Epoch 42/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.5580 - accuracy: 0.7253
# Epoch 43/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.5367 - accuracy: 0.7331
# Epoch 44/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.5213 - accuracy: 0.7526
# Epoch 45/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.5446 - accuracy: 0.7383
# Epoch 46/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.5341 - accuracy: 0.7409
# Epoch 47/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.5405 - accuracy: 0.7448
# Epoch 48/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.5320 - accuracy: 0.7474
# Epoch 49/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.5318 - accuracy: 0.7422
# Epoch 50/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.5429 - accuracy: 0.7409
# Epoch 51/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.5394 - accuracy: 0.7253
# Epoch 52/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.5225 - accuracy: 0.7409
# Epoch 53/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.5240 - accuracy: 0.7448
# Epoch 54/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.5190 - accuracy: 0.7370
# Epoch 55/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.5387 - accuracy: 0.7161
# Epoch 56/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.5321 - accuracy: 0.7435
# Epoch 57/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.5279 - accuracy: 0.7188
# Epoch 58/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.5362 - accuracy: 0.7344
# Epoch 59/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.5283 - accuracy: 0.7474
# Epoch 60/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.5261 - accuracy: 0.7448
# Epoch 61/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.5480 - accuracy: 0.7409
# Epoch 62/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.5409 - accuracy: 0.7318
# Epoch 63/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.5145 - accuracy: 0.7526
# Epoch 64/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.5086 - accuracy: 0.7357
# Epoch 65/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.5193 - accuracy: 0.7435
# Epoch 66/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.5214 - accuracy: 0.7422
# Epoch 67/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.5243 - accuracy: 0.7500
# Epoch 68/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.5132 - accuracy: 0.7461
# Epoch 69/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.5306 - accuracy: 0.7240
# Epoch 70/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.5122 - accuracy: 0.7591
# Epoch 71/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.5065 - accuracy: 0.7552
# Epoch 72/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.5047 - accuracy: 0.7682
# Epoch 73/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.5086 - accuracy: 0.7448
# Epoch 74/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.5166 - accuracy: 0.7539
# Epoch 75/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.5051 - accuracy: 0.7591
# Epoch 76/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.5122 - accuracy: 0.7591
# Epoch 77/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.5239 - accuracy: 0.7305
# Epoch 78/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.5010 - accuracy: 0.7630
# Epoch 79/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.5063 - accuracy: 0.7526
# Epoch 80/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.5037 - accuracy: 0.7526
# Epoch 81/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.5140 - accuracy: 0.7422
# Epoch 82/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4990 - accuracy: 0.7643
# Epoch 83/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4871 - accuracy: 0.7630
# Epoch 84/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.5160 - accuracy: 0.7513
# Epoch 85/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.5238 - accuracy: 0.7513
# Epoch 86/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.5121 - accuracy: 0.7422
# Epoch 87/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.5125 - accuracy: 0.7383
# Epoch 88/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.5046 - accuracy: 0.7409
# Epoch 89/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4947 - accuracy: 0.7669
# Epoch 90/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.5060 - accuracy: 0.7500
# Epoch 91/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.5029 - accuracy: 0.7630
# Epoch 92/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.5154 - accuracy: 0.7513
# Epoch 93/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.5176 - accuracy: 0.7591
# Epoch 94/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4931 - accuracy: 0.7682
# Epoch 95/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.5210 - accuracy: 0.7552
# Epoch 96/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.5125 - accuracy: 0.7513
# Epoch 97/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.5014 - accuracy: 0.7552
# Epoch 98/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.5121 - accuracy: 0.7591
# Epoch 99/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.5170 - accuracy: 0.7565
# Epoch 100/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4932 - accuracy: 0.7591
# Epoch 101/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4899 - accuracy: 0.7552
# Epoch 102/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.5027 - accuracy: 0.7669
# Epoch 103/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4934 - accuracy: 0.7682
# Epoch 104/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4890 - accuracy: 0.7643
# Epoch 105/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4933 - accuracy: 0.7656
# Epoch 106/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.5003 - accuracy: 0.7526
# Epoch 107/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4937 - accuracy: 0.7656
# Epoch 108/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4968 - accuracy: 0.7695
# Epoch 109/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4893 - accuracy: 0.7591
# Epoch 110/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.5061 - accuracy: 0.7643
# Epoch 111/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4952 - accuracy: 0.7604
# Epoch 112/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.5235 - accuracy: 0.7513
# Epoch 113/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4896 - accuracy: 0.7565
# Epoch 114/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4885 - accuracy: 0.7630
# Epoch 115/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4985 - accuracy: 0.7461
# Epoch 116/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4833 - accuracy: 0.7708
# Epoch 117/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4845 - accuracy: 0.7747
# Epoch 118/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4932 - accuracy: 0.7604
# Epoch 119/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.5040 - accuracy: 0.7292
# Epoch 120/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.5029 - accuracy: 0.7565
# Epoch 121/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4874 - accuracy: 0.7682
# Epoch 122/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4779 - accuracy: 0.7656
# Epoch 123/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.5040 - accuracy: 0.7539
# Epoch 124/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4998 - accuracy: 0.7604
# Epoch 125/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.5044 - accuracy: 0.7539
# Epoch 126/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.5012 - accuracy: 0.7461
# Epoch 127/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4871 - accuracy: 0.7682
# Epoch 128/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4939 - accuracy: 0.7682
# Epoch 129/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4782 - accuracy: 0.7747
# Epoch 130/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4811 - accuracy: 0.7669
# Epoch 131/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4799 - accuracy: 0.7682
# Epoch 132/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4798 - accuracy: 0.7682
# Epoch 133/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4862 - accuracy: 0.7565
# Epoch 134/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4931 - accuracy: 0.7747
# Epoch 135/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4777 - accuracy: 0.7826
# Epoch 136/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4943 - accuracy: 0.7708
# Epoch 137/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4729 - accuracy: 0.7643
# Epoch 138/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4824 - accuracy: 0.7747
# Epoch 139/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4777 - accuracy: 0.7721
# Epoch 140/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4833 - accuracy: 0.7643
# Epoch 141/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4800 - accuracy: 0.7747
# Epoch 142/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4904 - accuracy: 0.7643
# Epoch 143/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.5057 - accuracy: 0.7539
# Epoch 144/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4926 - accuracy: 0.7721
# Epoch 145/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4779 - accuracy: 0.7760
# Epoch 146/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4833 - accuracy: 0.7669
# Epoch 147/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4947 - accuracy: 0.7643
# Epoch 148/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4747 - accuracy: 0.7734
# Epoch 149/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4893 - accuracy: 0.7656
# Epoch 150/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.4802 - accuracy: 0.7799

# %%
# evaluate the model
scores = model.evaluate(X, Y)
print("%s: %.2f%%" % (model.metrics_names[1], scores[1]*100))
# Out:
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4659 - accuracy: 0.7917
# accuracy: 79.17%

# %% [markdown]
# # Multiclass Classification Of Flower Species

# %%
import numpy
import pandas
from keras.models import Sequential
from keras.layers import Dense
from keras.wrappers.scikit_learn import KerasClassifier
from keras.utils import np_utils
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold
from sklearn.preprocessing import LabelEncoder
from sklearn.pipeline import Pipeline

# %%
# fix random seed for reproducibility
seed = 7
numpy.random.seed(seed)

# %%
# load dataset
dataframe = pandas.read_csv("iris.csv", header=None)
dataset = dataframe.values
X = dataset[:,0:4]
Y = dataset[:,4]

# %%
# encode class values as integers
encoder = LabelEncoder()
encoder.fit(Y)
encoded_Y = encoder.transform(Y)
# convert integers to dummy variables (i.e. one hot encoded)
dummy_y = np_utils.to_categorical(encoded_Y)

# %%
# define baseline model
def baseline_model():
# create model
 model = Sequential()
 model.add(Dense(4, input_dim=4, init= normal , activation= relu ))
 model.add(Dense(3, init= normal , activation= sigmoid ))
# Compile model
 model.compile(loss= categorical_crossentropy , optimizer= adam , metrics=[ accuracy ])
 return model

# %%
estimator = KerasClassifier(build_fn=baseline_model, nb_epoch=200, batch_size=5, verbose=0)
# Out:
# C:\Users\LocalAcc\AppData\Local\Temp/ipykernel_12272/1436119445.py:1: DeprecationWarning: KerasClassifier is deprecated, use Sci-Keras (https://github.com/adriangb/scikeras) instead. See https://www.adriangb.com/scikeras/stable/migration.html for help migrating.
#   estimator = KerasClassifier(build_fn=baseline_model, nb_epoch=200, batch_size=5, verbose=0)

# %%
# Multiclass Classification with the Iris Flowers Dataset
import numpy
import pandas
from keras.models import Sequential
from keras.layers import Dense
from keras.wrappers.scikit_learn import KerasClassifier
from keras.utils import np_utils
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold
from sklearn.preprocessing import LabelEncoder
from sklearn.pipeline import Pipeline
# fix random seed for reproducibility
seed = 7
numpy.random.seed(seed)
# load dataset
dataframe = pandas.read_csv("iris.csv", header=None)
dataset = dataframe.values
X = dataset[:,0:4]
Y = dataset[:,4]
# encode class values as integers
encoder = LabelEncoder()
encoder.fit(Y)
encoded_Y = encoder.transform(Y)
# convert integers to dummy variables (i.e. one hot encoded)
dummy_y = np_utils.to_categorical(encoded_Y)
# define baseline model
def baseline_model():
# create model
 model = Sequential()
 model.add(Dense(4, input_dim=4 , activation= 'relu' ))
 model.add(Dense(3, activation= 'sigmoid' ))
# Compile model
 model.compile(loss= 'categorical_crossentropy' , optimizer= 'adam' , metrics=[ 'accuracy' ])
 return model
estimator = KerasClassifier(build_fn=baseline_model, nb_epoch=200, batch_size=5, verbose=0)
kfold = KFold(n_splits=10, shuffle=True, random_state=seed)
results = cross_val_score(estimator, X, dummy_y, cv=kfold)
print("Accuracy: %.2f%% (%.2f%%)" % (results.mean()*100, results.std()*100))
# Out:
# C:\Users\LocalAcc\AppData\Local\Temp/ipykernel_12272/2491290952.py:35: DeprecationWarning: KerasClassifier is deprecated, use Sci-Keras (https://github.com/adriangb/scikeras) instead. See https://www.adriangb.com/scikeras/stable/migration.html for help migrating.
#   estimator = KerasClassifier(build_fn=baseline_model, nb_epoch=200, batch_size=5, verbose=0)
# C:\Users\LocalAcc\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\LocalAcc\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\LocalAcc\anaconda3\lib\site-packages\keras\wrappers\scikit_learn.py", line 236, in fit
#     return super(KerasClassifier, self).fit(x, y, **kwargs)
#   File "C:\Users\LocalAcc\anaconda3\lib\site-packages\keras\wrappers\scikit_learn.py", line 164, in fit
#     history = self.model.fit(x, y, **fit_args)
#   File "C:\Users\LocalAcc\anaconda3\lib\site-packages\keras\utils\traceback_utils.py", line 67, in error_handler
#     raise e.with_traceback(filtered_tb) from None
#   File "C:\Users\LocalAcc\anaconda3\lib\site-packages\tensorflow\python\framework\func_graph.py", line 1147, in autograph_handler
#     raise e.ag_error_metadata.to_exception(e)
# ValueError: in user code:
#
#     File "C:\Users\LocalAcc\anaconda3\lib\site-packages\keras\engine\training.py", line 1021, in train_function  *
#         return step_function(self, iterator)
#     File "C:\Users\LocalAcc\anaconda3\lib\site-packages\keras\engine\training.py", line 1010, in step_function  **
#         outputs = model.distribute_strategy.run(run_step, args=(data,))
#     File "C:\Users\LocalAcc\anaconda3\lib\site-packages\keras\engine\training.py", line 1000, in run_step  **
#         outputs = model.train_step(data)
#     File "C:\Users\LocalAcc\anaconda3\lib\site-packages\keras\engine\training.py", line 860, in train_step
#         loss = self.compute_loss(x, y, y_pred, sample_weight)
#     File "C:\Users\LocalAcc\anaconda3\lib\site-packages\keras\engine\training.py", line 918, in compute_loss
#         return self.compiled_loss(
#     File "C:\Users\LocalAcc\anaconda3\lib\site-packages\keras\engine\compile_utils.py", line 201, in __call__
#         loss_value = loss_obj(y_t, y_p, sample_weight=sw)
#     File "C:\Users\LocalAcc\anaconda3\lib\site-packages\keras\losses.py", line 141, in __call__
#         losses = call_fn(y_true, y_pred)
#     File "C:\Users\LocalAcc\anaconda3\lib\site-packages\keras\losses.py", line 245, in call  **
#         return ag_fn(y_true, y_pred, **self._fn_kwargs)
#     File "C:\Users\LocalAcc\anaconda3\lib\site-packages\keras\losses.py", line 1789, in categorical_crossentropy
#         return backend.categorical_crossentropy(
#     File "C:\Users\LocalAcc\anaconda3\lib\site-packages\keras\backend.py", line 5083, in categorical_crossentropy
#         target.shape.assert_is_compatible_with(output.shape)
#
#     ValueError: Shapes (5, 4) and (5, 3) are incompatible
#
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\LocalAcc\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\LocalAcc\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\LocalAcc\anaconda3\lib\site-packages\keras\wrappers\scikit_learn.py", line 236, in fit
#     return super(KerasClassifier, self).fit(x, y, **kwargs)
#   File "C:\Users\LocalAcc\anaconda3\lib\site-packages\keras\wrappers\scikit_learn.py", line 164, in fit
#     history = self.model.fit(x, y, **fit_args)
#   File "C:\Users\LocalAcc\anaconda3\lib\site-packages\keras\utils\traceback_utils.py", line 67, in error_handler
#     raise e.with_traceback(filtered_tb) from None
#   File "C:\Users\LocalAcc\anaconda3\lib\site-packages\tensorflow\python\framework\func_graph.py", line 1147, in autograph_handler
#     raise e.ag_error_metadata.to_exception(e)
# ValueError: in user code:
#
#     File "C:\Users\LocalAcc\anaconda3\lib\site-packages\keras\engine\training.py", line 1021, in train_function  *
#         return step_function(self, iterator)
#     File "C:\Users\LocalAcc\anaconda3\lib\site-packages\keras\engine\training.py", line 1010, in step_function  **
#         outputs = model.distribute_strategy.run(run_step, args=(data,))
#     File "C:\Users\LocalAcc\anaconda3\lib\site-packages\keras\engine\training.py", line 1000, in run_step  **
#         outputs = model.train_step(data)
#     File "C:\Users\LocalAcc\anaconda3\lib\site-packages\keras\engine\training.py", line 860, in train_step
#         loss = self.compute_loss(x, y, y_pred, sample_weight)
#     File "C:\Users\LocalAcc\anaconda3\lib\site-packages\keras\engine\training.py", line 918, in compute_loss
#         return self.compiled_loss(
#     File "C:\Users\LocalAcc\anaconda3\lib\site-packages\keras\engine\compile_utils.py", line 201, in __call__
#         loss_value = loss_obj(y_t, y_p, sample_weight=sw)
#     File "C:\Users\LocalAcc\anaconda3\lib\site-packages\keras\losses.py", line 141, in __call__
#         losses = call_fn(y_true, y_pred)
#     File "C:\Users\LocalAcc\anaconda3\lib\site-packages\keras\losses.py", line 245, in call  **
#         return ag_fn(y_true, y_pred, **self._fn_kwargs)
#     File "C:\Users\LocalAcc\anaconda3\lib\site-packages\keras\losses.py", line 1789, in categorical_crossentropy
#         return backend.categorical_crossentropy(
#     File "C:\Users\LocalAcc\anaconda3\lib\site-packages\keras\backend.py", line 5083, in categorical_crossentropy
#         target.shape.assert_is_compatible_with(output.shape)
#
#     ValueError: Shapes (None, 4) and (None, 3) are incompatible
#
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\LocalAcc\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\LocalAcc\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\LocalAcc\anaconda3\lib\site-packages\keras\wrappers\scikit_learn.py", line 236, in fit
#     return super(KerasClassifier, self).fit(x, y, **kwargs)
#   File "C:\Users\LocalAcc\anaconda3\lib\site-packages\keras\wrappers\scikit_learn.py", line 164, in fit
#     history = self.model.fit(x, y, **fit_args)
#   File "C:\Users\LocalAcc\anaconda3\lib\site-packages\keras\utils\traceback_utils.py", line 67, in error_handler
#     raise e.with_traceback(filtered_tb) from None
#   File "C:\Users\LocalAcc\anaconda3\lib\site-packages\tensorflow\python\framework\func_graph.py", line 1147, in autograph_handler
#     raise e.ag_error_metadata.to_exception(e)
# ValueError: in user code:
#
#     File "C:\Users\LocalAcc\anaconda3\lib\site-packages\keras\engine\training.py", line 1021, in train_function  *
#         return step_function(self, iterator)
#     File "C:\Users\LocalAcc\anaconda3\lib\site-packages\keras\engine\training.py", line 1010, in step_function  **
#         outputs = model.distribute_strategy.run(run_step, args=(data,))
#     File "C:\Users\LocalAcc\anaconda3\lib\site-packages\keras\engine\training.py", line 1000, in run_step  **
#         outputs = model.train_step(data)
#     File "C:\Users\LocalAcc\anaconda3\lib\site-packages\keras\engine\training.py", line 860, in train_step
#         loss = self.compute_loss(x, y, y_pred, sample_weight)
#     File "C:\Users\LocalAcc\anaconda3\lib\site-packages\keras\engine\training.py", line 918, in compute_loss
#         return self.compiled_loss(
#     File "C:\Users\LocalAcc\anaconda3\lib\site-packages\keras\engine\compile_utils.py", line 201, in __call__
#         loss_value = loss_obj(y_t, y_p, sample_weight=sw)
#     File "C:\Users\LocalAcc\anaconda3\lib\site-packages\keras\losses.py", line 141, in __call__
#         losses = call_fn(y_true, y_pred)
#     File "C:\Users\LocalAcc\anaconda3\lib\site-packages\keras\losses.py", line 245, in call  **
#         return ag_fn(y_true, y_pred, **self._fn_kwargs)
#     File "C:\Users\LocalAcc\anaconda3\lib\site-packages\keras\losses.py", line 1789, in categorical_crossentropy
#         return backend.categorical_crossentropy(
#     File "C:\Users\LocalAcc\anaconda3\lib\site-packages\keras\backend.py", line 5083, in categorical_crossentropy
#         target.shape.assert_is_compatible_with(output.shape)
#
#     ValueError: Shapes (None, 4) and (None, 3) are incompatible
#
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\LocalAcc\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\LocalAcc\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\LocalAcc\anaconda3\lib\site-packages\keras\wrappers\scikit_learn.py", line 236, in fit
#     return super(KerasClassifier, self).fit(x, y, **kwargs)
#   File "C:\Users\LocalAcc\anaconda3\lib\site-packages\keras\wrappers\scikit_learn.py", line 164, in fit
#     history = self.model.fit(x, y, **fit_args)
#   File "C:\Users\LocalAcc\anaconda3\lib\site-packages\keras\utils\traceback_utils.py", line 67, in error_handler
#     raise e.with_traceback(filtered_tb) from None
#   File "C:\Users\LocalAcc\anaconda3\lib\site-packages\tensorflow\python\framework\func_graph.py", line 1147, in autograph_handler
#     raise e.ag_error_metadata.to_exception(e)
# ValueError: in user code:
#
#     File "C:\Users\LocalAcc\anaconda3\lib\site-packages\keras\engine\training.py", line 1021, in train_function  *
#         return step_function(self, iterator)
#     File "C:\Users\LocalAcc\anaconda3\lib\site-packages\keras\engine\training.py", line 1010, in step_function  **
#         outputs = model.distribute_strategy.run(run_step, args=(data,))
#     File "C:\Users\LocalAcc\anaconda3\lib\site-packages\keras\engine\training.py", line 1000, in run_step  **
#         outputs = model.train_step(data)
#     File "C:\Users\LocalAcc\anaconda3\lib\site-packages\keras\engine\training.py", line 860, in train_step
#         loss = self.compute_loss(x, y, y_pred, sample_weight)
#     File "C:\Users\LocalAcc\anaconda3\lib\site-packages\keras\engine\training.py", line 918, in compute_loss
#         return self.compiled_loss(
#     File "C:\Users\LocalAcc\anaconda3\lib\site-packages\keras\engine\compile_utils.py", line 201, in __call__
#         loss_value = loss_obj(y_t, y_p, sample_weight=sw)
#     File "C:\Users\LocalAcc\anaconda3\lib\site-packages\keras\losses.py", line 141, in __call__
#         losses = call_fn(y_true, y_pred)
#     File "C:\Users\LocalAcc\anaconda3\lib\site-packages\keras\losses.py", line 245, in call  **
#         return ag_fn(y_true, y_pred, **self._fn_kwargs)
#     File "C:\Users\LocalAcc\anaconda3\lib\site-packages\keras\losses.py", line 1789, in categorical_crossentropy
#         return backend.categorical_crossentropy(
#     File "C:\Users\LocalAcc\anaconda3\lib\site-packages\keras\backend.py", line 5083, in categorical_crossentropy
#         target.shape.assert_is_compatible_with(output.shape)
#
#     ValueError: Shapes (None, 4) and (None, 3) are incompatible
#
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\LocalAcc\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\LocalAcc\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\LocalAcc\anaconda3\lib\site-packages\keras\wrappers\scikit_learn.py", line 236, in fit
#     return super(KerasClassifier, self).fit(x, y, **kwargs)
#   File "C:\Users\LocalAcc\anaconda3\lib\site-packages\keras\wrappers\scikit_learn.py", line 164, in fit
#     history = self.model.fit(x, y, **fit_args)
#   File "C:\Users\LocalAcc\anaconda3\lib\site-packages\keras\utils\traceback_utils.py", line 67, in error_handler
#     raise e.with_traceback(filtered_tb) from None
#   File "C:\Users\LocalAcc\anaconda3\lib\site-packages\tensorflow\python\framework\func_graph.py", line 1147, in autograph_handler
#     raise e.ag_error_metadata.to_exception(e)
# ValueError: in user code:
#
#     File "C:\Users\LocalAcc\anaconda3\lib\site-packages\keras\engine\training.py", line 1021, in train_function  *
#         return step_function(self, iterator)
#     File "C:\Users\LocalAcc\anaconda3\lib\site-packages\keras\engine\training.py", line 1010, in step_function  **
#         outputs = model.distribute_strategy.run(run_step, args=(data,))
#     File "C:\Users\LocalAcc\anaconda3\lib\site-packages\keras\engine\training.py", line 1000, in run_step  **
#         outputs = model.train_step(data)
#     File "C:\Users\LocalAcc\anaconda3\lib\site-packages\keras\engine\training.py", line 860, in train_step
#         loss = self.compute_loss(x, y, y_pred, sample_weight)
#     File "C:\Users\LocalAcc\anaconda3\lib\site-packages\keras\engine\training.py", line 918, in compute_loss
#         return self.compiled_loss(
#     File "C:\Users\LocalAcc\anaconda3\lib\site-packages\keras\engine\compile_utils.py", line 201, in __call__
#         loss_value = loss_obj(y_t, y_p, sample_weight=sw)
#     File "C:\Users\LocalAcc\anaconda3\lib\site-packages\keras\losses.py", line 141, in __call__
#         losses = call_fn(y_true, y_pred)
#     File "C:\Users\LocalAcc\anaconda3\lib\site-packages\keras\losses.py", line 245, in call  **
#         return ag_fn(y_true, y_pred, **self._fn_kwargs)
#     File "C:\Users\LocalAcc\anaconda3\lib\site-packages\keras\losses.py", line 1789, in categorical_crossentropy
#         return backend.categorical_crossentropy(
#     File "C:\Users\LocalAcc\anaconda3\lib\site-packages\keras\backend.py", line 5083, in categorical_crossentropy
#         target.shape.assert_is_compatible_with(output.shape)
#
#     ValueError: Shapes (None, 4) and (None, 3) are incompatible
#
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\LocalAcc\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\LocalAcc\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\LocalAcc\anaconda3\lib\site-packages\keras\wrappers\scikit_learn.py", line 236, in fit
#     return super(KerasClassifier, self).fit(x, y, **kwargs)
#   File "C:\Users\LocalAcc\anaconda3\lib\site-packages\keras\wrappers\scikit_learn.py", line 164, in fit
#     history = self.model.fit(x, y, **fit_args)
#   File "C:\Users\LocalAcc\anaconda3\lib\site-packages\keras\utils\traceback_utils.py", line 67, in error_handler
#     raise e.with_traceback(filtered_tb) from None
#   File "C:\Users\LocalAcc\anaconda3\lib\site-packages\tensorflow\python\framework\func_graph.py", line 1147, in autograph_handler
#     raise e.ag_error_metadata.to_exception(e)
# ValueError: in user code:
#
#     File "C:\Users\LocalAcc\anaconda3\lib\site-packages\keras\engine\training.py", line 1021, in train_function  *
#         return step_function(self, iterator)
#     File "C:\Users\LocalAcc\anaconda3\lib\site-packages\keras\engine\training.py", line 1010, in step_function  **
#         outputs = model.distribute_strategy.run(run_step, args=(data,))
#     File "C:\Users\LocalAcc\anaconda3\lib\site-packages\keras\engine\training.py", line 1000, in run_step  **
#         outputs = model.train_step(data)
#     File "C:\Users\LocalAcc\anaconda3\lib\site-packages\keras\engine\training.py", line 860, in train_step
#         loss = self.compute_loss(x, y, y_pred, sample_weight)
#     File "C:\Users\LocalAcc\anaconda3\lib\site-packages\keras\engine\training.py", line 918, in compute_loss
#         return self.compiled_loss(
#     File "C:\Users\LocalAcc\anaconda3\lib\site-packages\keras\engine\compile_utils.py", line 201, in __call__
#         loss_value = loss_obj(y_t, y_p, sample_weight=sw)
#     File "C:\Users\LocalAcc\anaconda3\lib\site-packages\keras\losses.py", line 141, in __call__
#         losses = call_fn(y_true, y_pred)
#     File "C:\Users\LocalAcc\anaconda3\lib\site-packages\keras\losses.py", line 245, in call  **
#         return ag_fn(y_true, y_pred, **self._fn_kwargs)
#     File "C:\Users\LocalAcc\anaconda3\lib\site-packages\keras\losses.py", line 1789, in categorical_crossentropy
#         return backend.categorical_crossentropy(
#     File "C:\Users\LocalAcc\anaconda3\lib\site-packages\keras\backend.py", line 5083, in categorical_crossentropy
#         target.shape.assert_is_compatible_with(output.shape)
#
#     ValueError: Shapes (None, 4) and (None, 3) are incompatible
#
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\LocalAcc\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\LocalAcc\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\LocalAcc\anaconda3\lib\site-packages\keras\wrappers\scikit_learn.py", line 236, in fit
#     return super(KerasClassifier, self).fit(x, y, **kwargs)
#   File "C:\Users\LocalAcc\anaconda3\lib\site-packages\keras\wrappers\scikit_learn.py", line 164, in fit
#     history = self.model.fit(x, y, **fit_args)
#   File "C:\Users\LocalAcc\anaconda3\lib\site-packages\keras\utils\traceback_utils.py", line 67, in error_handler
#     raise e.with_traceback(filtered_tb) from None
#   File "C:\Users\LocalAcc\anaconda3\lib\site-packages\tensorflow\python\framework\func_graph.py", line 1147, in autograph_handler
#     raise e.ag_error_metadata.to_exception(e)
# ValueError: in user code:
#
#     File "C:\Users\LocalAcc\anaconda3\lib\site-packages\keras\engine\training.py", line 1021, in train_function  *
#         return step_function(self, iterator)
#     File "C:\Users\LocalAcc\anaconda3\lib\site-packages\keras\engine\training.py", line 1010, in step_function  **
#         outputs = model.distribute_strategy.run(run_step, args=(data,))
#     File "C:\Users\LocalAcc\anaconda3\lib\site-packages\keras\engine\training.py", line 1000, in run_step  **
#         outputs = model.train_step(data)
#     File "C:\Users\LocalAcc\anaconda3\lib\site-packages\keras\engine\training.py", line 860, in train_step
#         loss = self.compute_loss(x, y, y_pred, sample_weight)
#     File "C:\Users\LocalAcc\anaconda3\lib\site-packages\keras\engine\training.py", line 918, in compute_loss
#         return self.compiled_loss(
#     File "C:\Users\LocalAcc\anaconda3\lib\site-packages\keras\engine\compile_utils.py", line 201, in __call__
#         loss_value = loss_obj(y_t, y_p, sample_weight=sw)
#     File "C:\Users\LocalAcc\anaconda3\lib\site-packages\keras\losses.py", line 141, in __call__
#         losses = call_fn(y_true, y_pred)
#     File "C:\Users\LocalAcc\anaconda3\lib\site-packages\keras\losses.py", line 245, in call  **
#         return ag_fn(y_true, y_pred, **self._fn_kwargs)
#     File "C:\Users\LocalAcc\anaconda3\lib\site-packages\keras\losses.py", line 1789, in categorical_crossentropy
#         return backend.categorical_crossentropy(
#     File "C:\Users\LocalAcc\anaconda3\lib\site-packages\keras\backend.py", line 5083, in categorical_crossentropy
#         target.shape.assert_is_compatible_with(output.shape)
#
#     ValueError: Shapes (None, 4) and (None, 3) are incompatible
#
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\LocalAcc\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\LocalAcc\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\LocalAcc\anaconda3\lib\site-packages\keras\wrappers\scikit_learn.py", line 236, in fit
#     return super(KerasClassifier, self).fit(x, y, **kwargs)
#   File "C:\Users\LocalAcc\anaconda3\lib\site-packages\keras\wrappers\scikit_learn.py", line 164, in fit
#     history = self.model.fit(x, y, **fit_args)
#   File "C:\Users\LocalAcc\anaconda3\lib\site-packages\keras\utils\traceback_utils.py", line 67, in error_handler
#     raise e.with_traceback(filtered_tb) from None
#   File "C:\Users\LocalAcc\anaconda3\lib\site-packages\tensorflow\python\framework\func_graph.py", line 1147, in autograph_handler
#     raise e.ag_error_metadata.to_exception(e)
# ValueError: in user code:
#
#     File "C:\Users\LocalAcc\anaconda3\lib\site-packages\keras\engine\training.py", line 1021, in train_function  *
#         return step_function(self, iterator)
#     File "C:\Users\LocalAcc\anaconda3\lib\site-packages\keras\engine\training.py", line 1010, in step_function  **
#         outputs = model.distribute_strategy.run(run_step, args=(data,))
#     File "C:\Users\LocalAcc\anaconda3\lib\site-packages\keras\engine\training.py", line 1000, in run_step  **
#         outputs = model.train_step(data)
#     File "C:\Users\LocalAcc\anaconda3\lib\site-packages\keras\engine\training.py", line 860, in train_step
#         loss = self.compute_loss(x, y, y_pred, sample_weight)
#     File "C:\Users\LocalAcc\anaconda3\lib\site-packages\keras\engine\training.py", line 918, in compute_loss
#         return self.compiled_loss(
#     File "C:\Users\LocalAcc\anaconda3\lib\site-packages\keras\engine\compile_utils.py", line 201, in __call__
#         loss_value = loss_obj(y_t, y_p, sample_weight=sw)
#     File "C:\Users\LocalAcc\anaconda3\lib\site-packages\keras\losses.py", line 141, in __call__
#         losses = call_fn(y_true, y_pred)
#     File "C:\Users\LocalAcc\anaconda3\lib\site-packages\keras\losses.py", line 245, in call  **
#         return ag_fn(y_true, y_pred, **self._fn_kwargs)
#     File "C:\Users\LocalAcc\anaconda3\lib\site-packages\keras\losses.py", line 1789, in categorical_crossentropy
#         return backend.categorical_crossentropy(
#     File "C:\Users\LocalAcc\anaconda3\lib\site-packages\keras\backend.py", line 5083, in categorical_crossentropy
#         target.shape.assert_is_compatible_with(output.shape)
#
#     ValueError: Shapes (None, 4) and (None, 3) are incompatible
#
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\LocalAcc\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\LocalAcc\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\LocalAcc\anaconda3\lib\site-packages\keras\wrappers\scikit_learn.py", line 236, in fit
#     return super(KerasClassifier, self).fit(x, y, **kwargs)
#   File "C:\Users\LocalAcc\anaconda3\lib\site-packages\keras\wrappers\scikit_learn.py", line 164, in fit
#     history = self.model.fit(x, y, **fit_args)
#   File "C:\Users\LocalAcc\anaconda3\lib\site-packages\keras\utils\traceback_utils.py", line 67, in error_handler
#     raise e.with_traceback(filtered_tb) from None
#   File "C:\Users\LocalAcc\anaconda3\lib\site-packages\tensorflow\python\framework\func_graph.py", line 1147, in autograph_handler
#     raise e.ag_error_metadata.to_exception(e)
# ValueError: in user code:
#
#     File "C:\Users\LocalAcc\anaconda3\lib\site-packages\keras\engine\training.py", line 1021, in train_function  *
#         return step_function(self, iterator)
#     File "C:\Users\LocalAcc\anaconda3\lib\site-packages\keras\engine\training.py", line 1010, in step_function  **
#         outputs = model.distribute_strategy.run(run_step, args=(data,))
#     File "C:\Users\LocalAcc\anaconda3\lib\site-packages\keras\engine\training.py", line 1000, in run_step  **
#         outputs = model.train_step(data)
#     File "C:\Users\LocalAcc\anaconda3\lib\site-packages\keras\engine\training.py", line 860, in train_step
#         loss = self.compute_loss(x, y, y_pred, sample_weight)
#     File "C:\Users\LocalAcc\anaconda3\lib\site-packages\keras\engine\training.py", line 918, in compute_loss
#         return self.compiled_loss(
#     File "C:\Users\LocalAcc\anaconda3\lib\site-packages\keras\engine\compile_utils.py", line 201, in __call__
#         loss_value = loss_obj(y_t, y_p, sample_weight=sw)
#     File "C:\Users\LocalAcc\anaconda3\lib\site-packages\keras\losses.py", line 141, in __call__
#         losses = call_fn(y_true, y_pred)
#     File "C:\Users\LocalAcc\anaconda3\lib\site-packages\keras\losses.py", line 245, in call  **
#         return ag_fn(y_true, y_pred, **self._fn_kwargs)
#     File "C:\Users\LocalAcc\anaconda3\lib\site-packages\keras\losses.py", line 1789, in categorical_crossentropy
#         return backend.categorical_crossentropy(
#     File "C:\Users\LocalAcc\anaconda3\lib\site-packages\keras\backend.py", line 5083, in categorical_crossentropy
#         target.shape.assert_is_compatible_with(output.shape)
#
#     ValueError: Shapes (None, 4) and (None, 3) are incompatible
#
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# Accuracy: nan% (nan%)
# C:\Users\LocalAcc\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\LocalAcc\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\LocalAcc\anaconda3\lib\site-packages\keras\wrappers\scikit_learn.py", line 236, in fit
#     return super(KerasClassifier, self).fit(x, y, **kwargs)
#   File "C:\Users\LocalAcc\anaconda3\lib\site-packages\keras\wrappers\scikit_learn.py", line 164, in fit
#     history = self.model.fit(x, y, **fit_args)
#   File "C:\Users\LocalAcc\anaconda3\lib\site-packages\keras\utils\traceback_utils.py", line 67, in error_handler
#     raise e.with_traceback(filtered_tb) from None
#   File "C:\Users\LocalAcc\anaconda3\lib\site-packages\tensorflow\python\framework\func_graph.py", line 1147, in autograph_handler
#     raise e.ag_error_metadata.to_exception(e)
# ValueError: in user code:
#
#     File "C:\Users\LocalAcc\anaconda3\lib\site-packages\keras\engine\training.py", line 1021, in train_function  *
#         return step_function(self, iterator)
#     File "C:\Users\LocalAcc\anaconda3\lib\site-packages\keras\engine\training.py", line 1010, in step_function  **
#         outputs = model.distribute_strategy.run(run_step, args=(data,))
#     File "C:\Users\LocalAcc\anaconda3\lib\site-packages\keras\engine\training.py", line 1000, in run_step  **
#         outputs = model.train_step(data)
#     File "C:\Users\LocalAcc\anaconda3\lib\site-packages\keras\engine\training.py", line 860, in train_step
#         loss = self.compute_loss(x, y, y_pred, sample_weight)
#     File "C:\Users\LocalAcc\anaconda3\lib\site-packages\keras\engine\training.py", line 918, in compute_loss
#         return self.compiled_loss(
#     File "C:\Users\LocalAcc\anaconda3\lib\site-packages\keras\engine\compile_utils.py", line 201, in __call__
#         loss_value = loss_obj(y_t, y_p, sample_weight=sw)
#     File "C:\Users\LocalAcc\anaconda3\lib\site-packages\keras\losses.py", line 141, in __call__
#         losses = call_fn(y_true, y_pred)
#     File "C:\Users\LocalAcc\anaconda3\lib\site-packages\keras\losses.py", line 245, in call  **
#         return ag_fn(y_true, y_pred, **self._fn_kwargs)
#     File "C:\Users\LocalAcc\anaconda3\lib\site-packages\keras\losses.py", line 1789, in categorical_crossentropy
#         return backend.categorical_crossentropy(
#     File "C:\Users\LocalAcc\anaconda3\lib\site-packages\keras\backend.py", line 5083, in categorical_crossentropy
#         target.shape.assert_is_compatible_with(output.shape)
#
#     ValueError: Shapes (None, 4) and (None, 3) are incompatible
#
#
#   warnings.warn("Estimator fit failed. The score on this train-test"

# %% [markdown]
# # Dropout Regularization For Neural Networks

# %% [markdown]
# Dropout is a regularization technique for neural network models proposed by Srivastava, et al.
# in their 2014 paper Dropout: A Simple Way to Prevent Neural Networks from Overfitting1.
# Dropout is a technique where randomly selected neurons are ignored during training. They
# are dropped-out randomly

# %% [markdown]
# # Dropout Regularization in Keras

# %%
# Baseline Model on the Sonar Dataset
import numpy
import pandas
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Dropout
from keras.wrappers.scikit_learn import KerasClassifier
from keras.constraints import maxnorm
#from keras.optimizers import SGD
from sklearn.model_selection import cross_val_score
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import StratifiedKFold
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
# fix random seed for reproducibility
seed = 7
numpy.random.seed(seed)
# load dataset
dataframe = pandas.read_csv("sonar.csv", header=None)
dataset = dataframe.values
# split into input (X) and output (Y) variables
X = dataset[:,0:60]
Y = dataset[:,60]
# encode class values as integers
encoder = LabelEncoder()
encoder.fit(Y)
encoded_Y = encoder.transform(Y)
# baseline
def create_baseline():
# create model
    model = Sequential()
    model.add(Dense(60, input_dim=60, init= normal , activation= relu ))
    model.add(Dense(30, init= normal , activation= relu ))
    model.add(Dense(1, init= normal , activation= sigmoid ))
    # Compile model
    sgd = SGD(lr=0.01, momentum=0.8, decay=0.0, nesterov=False)
    model.compile(loss= binary_crossentropy , optimizer=sgd, metrics=[ accuracy ])
    return model

numpy.random.seed(seed)
estimators = []
estimators.append(( standardize , StandardScaler()))
estimators.append(( mlp , KerasClassifier(build_fn=create_baseline, nb_epoch=300,
batch_size=16, verbose=0)))
pipeline = Pipeline(estimators)
kfold = StratifiedKFold(n_splits=10, shuffle=True, random_state=seed)
results = cross_val_score(pipeline, X, encoded_Y, cv=kfold)
print("Baseline: %.2f%% (%.2f%%)" % (results.mean()*100, results.std()*100))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_12272/2768071727.py in <module>
#      40 numpy.random.seed(seed)
#      41 estimators = []
# ---> 42 estimators.append(( standardize , StandardScaler()))
#      43 estimators.append(( mlp , KerasClassifier(build_fn=create_baseline, nb_epoch=300,
#      44 batch_size=16, verbose=0)))
#
# NameError: name 'standardize' is not defined

# %%
# Plot ad hoc mnist instances
from keras.datasets import mnist
import cv2
import matplotlib.pyplot as plt
# load (downloaded if needed) the MNIST dataset
(X_train, y_train), (X_test, y_test) = mnist.load_data()
# plot 4 images as gray scale
plt.subplot(221)
plt.imshow(X_train[0], cmap=plt.get_cmap( gray ))
plt.subplot(222)
plt.imshow(X_train[1], cmap=plt.get_cmap( gray ))
plt.subplot(223)
plt.imshow(X_train[2], cmap=plt.get_cmap( gray ))
plt.subplot(224)
plt.imshow(X_train[3], cmap=plt.get_cmap( gray ))
# show the plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_12272/1261781348.py in <module>
#       7 # plot 4 images as gray scale
#       8 plt.subplot(221)
# ----> 9 plt.imshow(X_train[0], cmap=plt.get_cmap( gray ))
#      10 plt.subplot(222)
#      11 plt.imshow(X_train[1], cmap=plt.get_cmap( gray ))
#
# NameError: name 'gray' is not defined
